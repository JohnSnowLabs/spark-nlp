# %% [markdown]
# ![JohnSnowLabs](https://sparknlp.org/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp/blob/master/examples/util/OpenAIEmbeddings.ipynb)

# %% [markdown]
# ## OpenAIEmbeddings in SparkNLP

# %% [markdown]
# In this notebook, we'll explore the process of utilizing OpenAIEmbeddings within SparkNLP's framework.
#
# Spark NLP offers a seamless integration with various OpenAI APIs, presenting a powerful synergy. With the introduction of Spark NLP 5.1.0, leveraging the OpenAICompletition and OpenAIEmbeddings transformers becomes achievable. This integration not only ensures the utilization of OpenAI's capabilities but also capitalizes on Spark's inherent scalability advantages.

# %% [markdown]
# ## Spark NLP Settings

# %% [markdown]
# All you need to do is to setup your [OpenAI API Key](https://platform.openai.com/docs/api-reference/authentication) and add it to Spark properties

# %%
print("Enter your OPENAI API Key:")
OPENAI_API_KEY = input()

# %%
from sparknlp.annotator import *
from pyspark.ml import Pipeline

# %%
import sparknlp
# let's start Spark with Spark NLP
openai_params = {"spark.jsl.settings.openai.api.key": OPENAI_API_KEY}
spark = sparknlp.start(params=openai_params)
# Out:
# Apache Spark version: 3.4.0

# %%
document_assembler = DocumentAssembler() \
        .setInputCol("text") \
        .setOutputCol("document")

openai_embeddings = OpenAIEmbeddings() \
       .setInputCols("document") \
       .setOutputCol("embeddings") \
       .setModel("text-embedding-ada-002")

# Define the pipeline
pipeline = Pipeline(stages=[
    document_assembler, openai_embeddings
])

# %%
empty_df = spark.createDataFrame([[""]], ["text"])
sample_text= [["The food was delicious and the waiter..."]]
sample_df= spark.createDataFrame(sample_text).toDF("text")
sample_df.show()
# Out:
# +--------------------+
# |                text|
# +--------------------+
# |The food was deli...|
# +--------------------+

# %%
pipeline_model = pipeline.fit(empty_df)
embeddings_df = pipeline_model.transform(sample_df)

# %%
embeddings_df.select("embeddings").show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |embeddings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[{document, 0, 40, The food was delicious and the waiter..., {}, [0.0023063174, -0.009358601, 0.01578391, -0.007752274, -0.004726919, 0.014806145, -0.009809389, -0.038221695, -0.006882445, -0.028723413, 0.025206001, 0.01815848, -0.0035777285, -0.025548855, 4.888821E-4, -0.01627914, 0.028418656, 0.005352307, 0.009618915, -0.016545804, -0.015352169, 0.0042697825, 0.007072918, -0.0070856167, -0.0039364537, 0.018463237, 0.008704642, -0.022729846, 0.011466509, 0.023859989, 0.015580738, -0.0035205863, -0.034894757, -0.004158673, -0.026056783, -0.02153621, -0.005755476, 0.0117331715, 0.008374488, 0.004079309, 0.019187037, -0.014387103, 0.008926861, 0.0063522933, -0.04576445, 0.01780293, -0.0054856385, -7.607038E-4, -0.02204414, -0.0038126458, 0.021015583, -0.017498171, -0.011758568, -0.022526674, 0.016406123, 0.01715532, -0.008514169, 0.001606327, 0.025066322, -0.025015527, 0.0077776704, 0.0058348402, -0.022158425, 0.003052339, -0.006155471, -0.025332984, -0.008126872, 0.0011198259, 2.167629E-5, 0.0046221586, 0.020647334, 0.013510925, 0.0046729515, -0.015987081, 0.016583899, -0.00893956, -0.00756815, 0.013650605, -0.006958634, 0.005377704, 0.009904625, -0.04589143, 0.0030158313, 0.023961574, 0.022971112, 0.00706022, -0.023656817, 0.00994272, -0.0065903855, -0.033243988, -0.002547584, 0.019834647, 0.0017777532, 0.0010920485, -0.02269175, 0.004993582, 0.015377565, 0.03164401, -0.0054380205, -0.016050572, -0.0052062776, 0.019847345, -0.009390347, -0.0067554624, -0.031212268, -0.00943479, -0.015212488, -0.02890119, 0.020952092, -0.018348953, -0.0030094823, 0.012660143, 0.0052538957, -0.049472332, -0.04294544, -3.8709783E-4, 0.021574305, -0.016799768, 0.0065522906, -0.041447047, 9.6903427E-4, 0.033523347, 0.01311728, -0.010431603, -4.9880263E-4, 0.01845054, 1.2608954E-4, -0.0131299775, 0.011796663, 0.0058348402, 0.0071300603, 0.008552263, 0.018412445, -7.2935503E-4, -0.019123545, 0.02190446, -0.029739272, -0.0043745427, 0.0014626782, -0.005168183, 0.015022015, 0.021320341, -0.018818788, 0.010977627, -0.0074411673, 0.02255207, 0.019148942, 0.014958524, -0.0035745539, 0.0062665804, 0.025599647, -0.027783744, 0.036647115, -0.0045300964, 0.013815682, 0.007987192, -0.0056284936, 0.010298271, -0.005850713, -0.008730038, 0.010641123, -8.482026E-6, 0.032228127, -0.023733007, -0.0025063145, 0.030247202, 0.029637687, 0.016533105, 0.0021237803, 9.341141E-4, -0.011561746, 0.01859022, -0.007542753, 0.007530055, -0.0010658583, 0.0045427945, 0.009904625, -0.007606244, -0.006247533, -0.0058030947, -0.028266277, 0.0043205754, 0.029205946, 0.024939338, -0.015644228, -0.018272763, 0.0075491024, 0.008596707, -0.011676029, -0.0063808644, 0.0020301307, 0.03690108, -0.002461871, -0.020761618, -0.6895651, -0.019542588, 0.0035872522, 0.006647527, 0.028291672, 0.023390153, 0.007218948, 0.010539537, 0.009555424, -0.009549075, -0.02125685, 5.1785E-5, 0.019682268, 0.002207906, -0.009498281, -0.0020920346, -3.5059042E-4, 0.006647527, -0.041243877, 0.011269686, -0.013434735, 0.027834537, -0.011396668, 1.6279538E-4, 0.015390264, -5.2221504E-4, 0.0144125, -0.00850147, -0.01888228, -0.017675947, -0.009326856, 0.02457109, 0.012863315, -0.008837974, 0.034970947, -0.005145961, -0.02421554, 0.02412665, -0.0037205836, 0.030958304, -0.015022015, -0.023275869, 0.03012022, 0.00684435, 0.010120495, 0.011447461, 0.030348787, 0.01757436, 0.0021221929, -0.0067554624, 0.009752247, 0.016672786, 0.003603125, 0.027885329, 0.0040888325, 0.0030412278, 0.029815461, -0.016812466, 0.0021650495, 0.023212379, 0.011790314, 0.014323612, -0.01966957, -0.02945991, -0.0015618833, 0.018310858, -0.0027063119, 0.019148942, 0.027580572, -0.008469724, 0.012368083, 0.002831707, -0.0052126264, 0.0064602285, 0.009390347, 0.02255207, 0.023504438, 0.0010301445, 0.018971168, -0.0029840858, -0.006888794, -0.010139543, -0.007891955, -0.0072379955, 0.020634636, 0.0107935015, -0.029840859, -0.0038443913, 0.0026761536, -0.018894978, 0.029917048, 0.024634581, -0.0044634305, 0.026463127, 0.017523568, 0.04114229, -0. ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
