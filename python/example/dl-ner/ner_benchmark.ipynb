# %%
import sys
sys.path.append('../../')

from pyspark.sql import SparkSession
from pyspark.ml import Pipeline

from sparknlp.annotator import *
from sparknlp.common import *
from sparknlp.base import *

import zipfile
import os
from pathlib import Path
import urllib.request

# %%
spark = SparkSession.builder \
    .appName("ner")\
    .master("local[1]")\
    .config("spark.driver.memory","8G")\
    .config("spark.driver.maxResultS1ize", "2G")\
    .config("spark.jar", "lib/sparknlp.jar")\
    .config("spark.kryoserializer.buffer.max", "500m")\
    .getOrCreate()

# %% [markdown]
# 1. Download CoNLL2003 dataset
# 2. Save 3 files eng.train, eng.testa, eng.testa, into working dir ./

# %%
# Example how to download CoNLL 2003 Dataset
def download_conll2003_file(file):    
    if not Path(file).is_file():
        url = "https://raw.githubusercontent.com/patverga/torch-ner-nlp-from-scratch/master/data/conll2003/" + file
        urllib.request.urlretrieve(url, file)
        
download_conll2003_file("eng.train")
download_conll2003_file("eng.testa")
download_conll2003_file("eng.testb")

# %% [markdown]
# 3 Download Glove word embeddings

# %%
file = "glove.6B.zip"
if not Path("glove.6B.zip").is_file():
    url = "http://nlp.stanford.edu/data/glove.6B.zip"
    print("Start downoading Glove Word Embeddings. It will take some time, please wait...")
    urllib.request.urlretrieve(url, "glove.6B.zip")
    print("Downloading finished")
    
if not Path("glove.6B.100d.txt").is_file():
    zip_ref = zipfile.ZipFile(file, 'r')
    zip_ref.extractall("./")
    zip_ref.close()

# %%
from pyspark.sql.types import *

class Annotation:
    def __init__(self, annotatorType, begin, end, result, metadata):
        self.annotatorType = annotatorType
        self.begin = begin
        self.end = end
        self.result = result
        self.metadata = metadata

        
annotation_schema = StructType([
    StructField("annotatorType", StringType()),
    StructField("begin", IntegerType(), False),
    StructField("end", IntegerType(), False),
    StructField("result", StringType()),
    StructField("metadata", MapType(StringType(), StringType()))
])
    


def readDataset(file, doc_column = "text", label_column = "label"):
    global spark
    
    result = []
    doc = ""
    labels = []

    with open(file) as f:
        for line in f:
            items = line.split(' ')
            word = items[0]
            if word == "-DOCSTART-":
                result.append((doc, labels))
                doc = ""
                labels = []
            elif len(items) <= 1:
                doc = doc + " \n"
            else:
                if len(doc) > 0:
                    doc = doc + " "

                begin = len(doc)
                doc = doc + word
                end = len(doc) - 1
                ner = items[3]
                labels.append(Annotation("named_entity", begin, end, ner, {}))

    if doc:
        result.append((doc, labels))
    
    global annotation_schema
    
    schema =  StructType([
      StructField(doc_column, StringType()),
      StructField(label_column, ArrayType(annotation_schema))
    ])
    
    
    return spark.createDataFrame(result, schema = schema)

# %%
import time

def get_pipeline():
    documentAssembler = DocumentAssembler()\
      .setInputCol("text")\
      .setOutputCol("document")

    sentenceDetector = SentenceDetector()\
      .setInputCols(["document"])\
      .setOutputCol("sentence")

    tokenizer = Tokenizer()\
      .setInputCols(["document"])\
      .setOutputCol("token")

    nerTagger = NerDLApproach()\
      .setInputCols(["sentence", "token"])\
      .setLabelColumn("label")\
      .setOutputCol("ner")\
      .setMaxEpochs(10)\
      .setExternalDataset("file://" + os.getcwd() + "/eng.train")\
      .setEmbeddingsSource("file://" + os.getcwd() + "/glove.6B.100d.txt", 100, 2)\
      .setRandomSeed(0)\
      .setVerbose(2)

    converter = NerConverter()\
      .setInputCols(["document", "token", "ner"])\
      .setOutputCol("ner_span")
      
    pipeline = Pipeline(
        stages = [
        documentAssembler,
        sentenceDetector,
        tokenizer,
        nerTagger,
        converter
      ])
    
    return pipeline


def train_model(file):
    global spark
    
    print("Dataset Reading")
    
    start = time.time()
    dataset = readDataset(file)
    print("Done, {}\n".format(time.time() - start))

    print("Start fitting")
    pipeline = get_pipeline()

    return pipeline.fit(dataset)

# %%
from pyspark.sql.functions import col, udf, explode


def get_dataset_for_analysis(file, model):
    global spark
    
    print("Dataset Reading")
    
    start = time.time()
    dataset = readDataset(file)
    print("Done, {}\n".format(time.time() - start))
    
    predicted = model.transform(dataset)
    
    global annotation_schema
    
    zip_annotations = udf(
      lambda x, y: list(zip(x, y)),
      ArrayType(StructType([
          StructField("predicted", annotation_schema),
          StructField("label", annotation_schema)
      ]))
    )
    
    return predicted\
        .withColumn("result", zip_annotations("ner", "label"))\
        .select(explode("result").alias("result"))\
        .select(
            col("result.predicted").alias("predicted"), 
            col("result.label").alias("label")
        )
        
def printStat(label, correct, predicted, predictedCorrect):
    prec = predictedCorrect / predicted if predicted > 0 else 0
    rec = predictedCorrect / correct if correct > 0 else 0
    f1 = (2*prec*rec)/(prec + rec) if prec + rec > 0 else 0
    
    print("{}\t{}\t{}\t{}".format(label, prec, rec, f1))
        

def test_dataset(file, model, ignore_tokenize_misses=True):
    global spark
    
    started = time.time()

    df = readDataset(file)
    transformed = model.transform(df).select("label", "ner")

    labels = []
    predictedLabels = []

    for line in transformed.collect():
        label = line[0]
        ner = line[1]
        ner = {(a["begin"], a["end"]):a["result"] for a in ner}

        for a in label:
            key = (a["begin"], a["end"])

            label = a["result"].strip()
            predictedLabel = ner.get(key, "O").strip()
            
            if key not in ner and ignore_tokenize_misses:
                continue
                
            labels.append(label)
            predictedLabels.append(predictedLabel)
        

    correct = {}
    predicted = {}
    predictedCorrect = {}


    print(len(labels))

    for (lPredicted, lCorrect) in zip(predictedLabels, labels):
        correct[lCorrect] = correct.get(lCorrect, 0) + 1
        predicted[lPredicted] = predicted.get(lPredicted, 0) + 1

        if lCorrect == lPredicted:
            predictedCorrect[lPredicted] = predictedCorrect.get(lPredicted, 0) + 1

    correct = { key: correct[key] for key in correct.keys() if key != 'O'}
    predicted = { key: predicted[key] for key in predicted.keys() if key != 'O'}
    predictedCorrect = { key: predictedCorrect[key] for key in predictedCorrect.keys() if key != 'O'}

    tags = set(list(correct.keys()) + list(predicted.keys()))

    print("label\tprec\trec\tf1")
    totalCorrect = sum(correct.values())
    totalPredicted = sum(predicted.values())
    totalPredictedCorrect = sum(predictedCorrect.values())

    printStat("Total", totalCorrect, totalPredicted, totalPredictedCorrect)

    for label in tags:
        printStat(label, correct.get(label, 0), predicted.get(label, 0), predictedCorrect.get(label, 0))

# %%
import os.path

folder = '.'
train_file = os.path.join(folder, "eng.train")
test_file_a = os.path.join(folder, "eng.testa")
test_file_b = os.path.join(folder, "eng.testb")

# %%
model = train_model(train_file)
# Out:
# Dataset Reading
# Done, 4.325708627700806
#
# Start fitting

# %%
print("\nQuality on training data")
test_dataset(train_file, model)

print("\n\nQuality on validation data")
test_dataset(test_file_a, model)

print("\n\nQuality on test data")
test_dataset(test_file_b, model)
# Out:
# Quality on training data
# 200019
# label	prec	rec	f1
# Total	0.711194940641296	0.3797955858391349	0.4951623182248315
# B-MISC	0	0.0	0
# B-LOC	0	0.0	0
# I-MISC	0.6804444444444444	0.34212290502793297	0.45531598513011157
# I-LOC	0.7260544815465729	0.40050896752302473	0.5162449234614183
# B-ORG	0	0.0	0
# I-PER	0.7694149334131378	0.4643727986995394	0.5791845010137419
# I-ORG	0.6258533362695442	0.2875645047050491	0.3940654464780921
#
#
# Quality on validation data
# 50487
# label	prec	rec	f1
# Total	0.7347897100857493	0.42271552736669016	0.5366835669549658
# B-MISC	0	0.0	0
# I-MISC	0.7145061728395061	0.3698083067092652	0.4873684210526315
# I-LOC	0.739448051948052	0.4373499759961594	0.5496229260935144
# I-PER	0.8011695906432749	0.5262483994878361	0.6352395672333848
# I-ORG	0.6014492753623188	0.2832764505119454	0.3851508120649652
#
#
# Quality on test data
# 45488
# label	prec	rec	f1
# Total	0.712688381137579	0.3635912698412698	0.48152405977993107
# B-MISC	0	0.0	0
# B-LOC	0	0.0	0
# I-MISC	0.6385542168674698	0.35333333333333333	0.45493562231759654
# I-LOC	0.7377495462794919	0.42632406921866806	0.5403788634097707
# B-ORG	0	0.0	0
# I-PER	0.7733411626541398	0.4766558089033659	0.5897895208240035
# I-ORG	0.5967940813810111	0.19563459983831852	0.29467275494672757

# %%
df = get_dataset_for_analysis(test_file_a, model)
df.show()
# Out:
# Dataset Reading
# Done, 0.6434798240661621
#
# +--------------------+--------------------+
# |           predicted|               label|
# +--------------------+--------------------+
# |[named_entity,3,9...|[named_entity,3,9...|
# |[named_entity,11,...|[named_entity,11,...|
# |[named_entity,13,...|[named_entity,13,...|
# |[named_entity,28,...|[named_entity,28,...|
# |[named_entity,33,...|[named_entity,33,...|
# |[named_entity,38,...|[named_entity,38,...|
# |[named_entity,41,...|[named_entity,41,...|
# |[named_entity,45,...|[named_entity,45,...|
# |[named_entity,51,...|[named_entity,51,...|
# |[named_entity,59,...|[named_entity,59,...|
# |[named_entity,67,...|[named_entity,67,...|
# |[named_entity,71,...|[named_entity,71,...|
# |[named_entity,78,...|[named_entity,78,...|
# |[named_entity,91,...|[named_entity,91,...|
# |[named_entity,96,...|[named_entity,96,...|
# |[named_entity,103...|[named_entity,103...|
# |[named_entity,115...|[named_entity,115...|
# |[named_entity,120...|[named_entity,120...|
# |[named_entity,128...|[named_entity,128...|
# |[named_entity,133...|[named_entity,133...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
get_pipeline().write().overwrite().save("./crf_pipeline")
model.write().overwrite().save("./crf_model")

# %%
from pyspark.ml import PipelineModel, Pipeline

Pipeline.read().load("./crf_pipeline")
sameModel = PipelineModel.read().load("./crf_model")

# %%
print("\nQuality on training data")
test_dataset(train_file, sameModel)

print("\n\nQuality on validation data")
test_dataset(test_file_a, sameModel)

print("\n\nQuality on test data")
test_dataset(test_file_b, sameModel)
# Out:
# Quality on training data
# []
# []
# [Row(annotatorType='named_entity', begin=3, end=4, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=6, end=12, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=14, end=19, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=21, end=24, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=26, end=27, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=29, end=35, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=37, end=43, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=45, end=48, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=50, end=50, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=54, end=58, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=60, end=68, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=72, end=79, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=81, end=90, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=94, end=96, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=98, end=105, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=107, end=116, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=118, end=121, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=123, end=124, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=126, end=133, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=135, end=136, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=138, end=146, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=148, end=151, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=153, end=158, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=160, end=165, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=167, end=168, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=170, end=178, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=180, end=181, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=183, end=186, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=188, end=194, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=196, end=199, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=201, end=205, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=207, end=216, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=218, end=226, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=228, end=234, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=236, end=238, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=240, end=242, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=244, end=250, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=252, end=254, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=256, end=257, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=259, end=269, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=271, end=272, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=274, end=278, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=280, end=280, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=284, end=290, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=292, end=293, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=295, end=308, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=310, end=311, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=313, end=315, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=317, en ...
# [Row(annotatorType='named_entity', begin=3, end=4, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=6, end=12, result='O', metadata={}), Row(annotatorType='named_entity', begin=14, end=19, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=21, end=24, result='O', metadata={}), Row(annotatorType='named_entity', begin=26, end=27, result='O', metadata={}), Row(annotatorType='named_entity', begin=29, end=35, result='O', metadata={}), Row(annotatorType='named_entity', begin=37, end=43, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=45, end=48, result='O', metadata={}), Row(annotatorType='named_entity', begin=50, end=50, result='O', metadata={}), Row(annotatorType='named_entity', begin=54, end=58, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=60, end=68, result='I-ORG', metadata={}), Row(annotatorType='named_entity', begin=72, end=79, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=81, end=90, result='O', metadata={}), Row(annotatorType='named_entity', begin=94, end=96, result='O', metadata={}), Row(annotatorType='named_entity', begin=98, end=105, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=107, end=116, result='I-ORG', metadata={}), Row(annotatorType='named_entity', begin=118, end=121, result='O', metadata={}), Row(annotatorType='named_entity', begin=123, end=124, result='O', metadata={}), Row(annotatorType='named_entity', begin=126, end=133, result='O', metadata={}), Row(annotatorType='named_entity', begin=135, end=136, result='O', metadata={}), Row(annotatorType='named_entity', begin=138, end=146, result='O', metadata={}), Row(annotatorType='named_entity', begin=148, end=151, result='O', metadata={}), Row(annotatorType='named_entity', begin=153, end=158, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=160, end=165, result='O', metadata={}), Row(annotatorType='named_entity', begin=167, end=168, result='O', metadata={}), Row(annotatorType='named_entity', begin=170, end=178, result='O', metadata={}), Row(annotatorType='named_entity', begin=180, end=181, result='O', metadata={}), Row(annotatorType='named_entity', begin=183, end=186, result='O', metadata={}), Row(annotatorType='named_entity', begin=188, end=194, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=196, end=199, result='O', metadata={}), Row(annotatorType='named_entity', begin=201, end=205, result='O', metadata={}), Row(annotatorType='named_entity', begin=207, end=216, result='O', metadata={}), Row(annotatorType='named_entity', begin=218, end=226, result='O', metadata={}), Row(annotatorType='named_entity', begin=228, end=234, result='O', metadata={}), Row(annotatorType='named_entity', begin=236, end=238, result='O', metadata={}), Row(annotatorType='named_entity', begin=240, end=242, result='O', metadata={}), Row(annotatorType='named_entity', begin=244, end=250, result='O', metadata={}), Row(annotatorType='named_entity', begin=252, end=254, result='O', metadata={}), Row(annotatorType='named_entity', begin=256, end=257, result='O', metadata={}), Row(annotatorType='named_entity', begin=259, end=269, result='O', metadata={}), Row(annotatorType='named_entity', begin=271, end=272, result='O', metadata={}), Row(annotatorType='named_entity', begin=274, end=278, result='O', metadata={}), Row(annotatorType='named_entity', begin=280, end=280, result='O', metadata={}), Row(annotatorType='named_entity', begin=284, end=290, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=292, end=292, result='O', metadata={}), Row(annotatorType='named_entity', begin=293, end=293, result='O', metadata={}), Row(annotatorType='named_entity', begin=295, end=308, result='O', metadata={}), Row(annotatorType='named_entity', begin=310, end=311, result='O', metadata={}), Row(annotatorType='named_entity', begin=313, end=315, result='O', metadata={}), Row(annotatorType='named_entity', begin=317, end=324, result= ...
# [Row(annotatorType='named_entity', begin=3, end=6, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=8, end=14, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=16, end=19, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=21, end=25, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=27, end=31, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=33, end=35, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=37, end=42, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=44, end=44, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=46, end=51, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=53, end=53, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=57, end=62, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=64, end=73, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=77, end=77, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=79, end=82, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=84, end=88, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=90, end=100, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=102, end=106, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=108, end=109, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=111, end=111, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=113, end=116, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=118, end=119, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=121, end=124, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=126, end=131, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=133, end=138, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=140, end=143, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=145, end=151, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=153, end=155, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=157, end=160, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=162, end=164, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=166, end=171, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=173, end=173, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=175, end=180, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=182, end=183, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=185, end=192, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=194, end=195, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=197, end=198, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=200, end=206, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=208, end=209, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=211, end=214, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=216, end=217, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=219, end=221, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=223, end=226, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=228, end=235, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=237, end=238, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=240, end=248, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=250, end=260, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=262, end=262, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=266, end=266, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=268, end=274, result='I-LOC\n', metad ...
# [Row(annotatorType='named_entity', begin=3, end=6, result='O', metadata={}), Row(annotatorType='named_entity', begin=8, end=14, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=16, end=19, result='O', metadata={}), Row(annotatorType='named_entity', begin=21, end=25, result='O', metadata={}), Row(annotatorType='named_entity', begin=27, end=31, result='O', metadata={}), Row(annotatorType='named_entity', begin=33, end=35, result='O', metadata={}), Row(annotatorType='named_entity', begin=37, end=42, result='O', metadata={}), Row(annotatorType='named_entity', begin=44, end=44, result='O', metadata={}), Row(annotatorType='named_entity', begin=46, end=51, result='O', metadata={}), Row(annotatorType='named_entity', begin=53, end=53, result='O', metadata={}), Row(annotatorType='named_entity', begin=57, end=62, result='O', metadata={}), Row(annotatorType='named_entity', begin=64, end=73, result='O', metadata={}), Row(annotatorType='named_entity', begin=77, end=77, result='O', metadata={}), Row(annotatorType='named_entity', begin=79, end=82, result='O', metadata={}), Row(annotatorType='named_entity', begin=84, end=88, result='O', metadata={}), Row(annotatorType='named_entity', begin=90, end=100, result='O', metadata={}), Row(annotatorType='named_entity', begin=102, end=106, result='O', metadata={}), Row(annotatorType='named_entity', begin=108, end=109, result='O', metadata={}), Row(annotatorType='named_entity', begin=111, end=111, result='O', metadata={}), Row(annotatorType='named_entity', begin=113, end=116, result='O', metadata={}), Row(annotatorType='named_entity', begin=118, end=119, result='O', metadata={}), Row(annotatorType='named_entity', begin=121, end=124, result='O', metadata={}), Row(annotatorType='named_entity', begin=126, end=131, result='O', metadata={}), Row(annotatorType='named_entity', begin=133, end=138, result='O', metadata={}), Row(annotatorType='named_entity', begin=140, end=143, result='O', metadata={}), Row(annotatorType='named_entity', begin=145, end=151, result='O', metadata={}), Row(annotatorType='named_entity', begin=153, end=155, result='O', metadata={}), Row(annotatorType='named_entity', begin=157, end=160, result='O', metadata={}), Row(annotatorType='named_entity', begin=162, end=164, result='O', metadata={}), Row(annotatorType='named_entity', begin=166, end=171, result='O', metadata={}), Row(annotatorType='named_entity', begin=173, end=173, result='O', metadata={}), Row(annotatorType='named_entity', begin=175, end=180, result='O', metadata={}), Row(annotatorType='named_entity', begin=182, end=183, result='O', metadata={}), Row(annotatorType='named_entity', begin=185, end=192, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=194, end=195, result='O', metadata={}), Row(annotatorType='named_entity', begin=197, end=198, result='O', metadata={}), Row(annotatorType='named_entity', begin=200, end=206, result='O', metadata={}), Row(annotatorType='named_entity', begin=208, end=209, result='O', metadata={}), Row(annotatorType='named_entity', begin=211, end=214, result='O', metadata={}), Row(annotatorType='named_entity', begin=216, end=217, result='O', metadata={}), Row(annotatorType='named_entity', begin=219, end=221, result='O', metadata={}), Row(annotatorType='named_entity', begin=223, end=226, result='O', metadata={}), Row(annotatorType='named_entity', begin=228, end=235, result='O', metadata={}), Row(annotatorType='named_entity', begin=237, end=237, result='O', metadata={}), Row(annotatorType='named_entity', begin=238, end=238, result='O', metadata={}), Row(annotatorType='named_entity', begin=240, end=248, result='O', metadata={}), Row(annotatorType='named_entity', begin=250, end=260, result='O', metadata={}), Row(annotatorType='named_entity', begin=262, end=262, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=266, end=266, result='O', metadata={}), Row(annotatorType='named_entity', begin=268, end=274, result='O', metadata={}), Row(annotatorType='na ...
# [Row(annotatorType='named_entity', begin=3, end=7, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=9, end=12, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=14, end=19, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=21, end=26, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=28, end=37, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=39, end=41, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=43, end=47, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=49, end=49, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=53, end=59, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=61, end=70, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=74, end=78, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=80, end=81, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=83, end=90, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=92, end=98, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=100, end=105, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=107, end=108, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=110, end=117, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=119, end=121, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=123, end=132, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=134, end=136, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=138, end=138, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=140, end=149, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=151, end=152, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=154, end=158, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=160, end=165, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=167, end=169, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=171, end=176, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=178, end=183, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=185, end=188, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=190, end=190, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=192, end=196, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=198, end=199, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=201, end=207, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=209, end=210, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=212, end=220, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=222, end=225, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=227, end=235, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=237, end=240, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=242, end=245, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=247, end=250, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=252, end=255, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=257, end=260, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=262, end=271, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=273, end=279, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=281, end=281, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=285, end=292, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=294, end=297, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=299, end=303, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=305,  ...
# [Row(annotatorType='named_entity', begin=3, end=7, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=9, end=12, result='O', metadata={}), Row(annotatorType='named_entity', begin=14, end=19, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=21, end=26, result='O', metadata={}), Row(annotatorType='named_entity', begin=28, end=37, result='O', metadata={}), Row(annotatorType='named_entity', begin=39, end=41, result='O', metadata={}), Row(annotatorType='named_entity', begin=43, end=47, result='O', metadata={}), Row(annotatorType='named_entity', begin=49, end=49, result='O', metadata={}), Row(annotatorType='named_entity', begin=53, end=59, result='O', metadata={}), Row(annotatorType='named_entity', begin=61, end=70, result='O', metadata={}), Row(annotatorType='named_entity', begin=74, end=78, result='O', metadata={}), Row(annotatorType='named_entity', begin=80, end=81, result='O', metadata={}), Row(annotatorType='named_entity', begin=83, end=90, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=92, end=98, result='O', metadata={}), Row(annotatorType='named_entity', begin=100, end=105, result='O', metadata={}), Row(annotatorType='named_entity', begin=107, end=108, result='O', metadata={}), Row(annotatorType='named_entity', begin=110, end=117, result='O', metadata={}), Row(annotatorType='named_entity', begin=119, end=121, result='O', metadata={}), Row(annotatorType='named_entity', begin=123, end=132, result='O', metadata={}), Row(annotatorType='named_entity', begin=134, end=136, result='O', metadata={}), Row(annotatorType='named_entity', begin=138, end=138, result='O', metadata={}), Row(annotatorType='named_entity', begin=140, end=149, result='O', metadata={}), Row(annotatorType='named_entity', begin=151, end=152, result='O', metadata={}), Row(annotatorType='named_entity', begin=154, end=158, result='O', metadata={}), Row(annotatorType='named_entity', begin=160, end=165, result='O', metadata={}), Row(annotatorType='named_entity', begin=167, end=169, result='O', metadata={}), Row(annotatorType='named_entity', begin=171, end=176, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=178, end=183, result='O', metadata={}), Row(annotatorType='named_entity', begin=185, end=188, result='O', metadata={}), Row(annotatorType='named_entity', begin=190, end=190, result='O', metadata={}), Row(annotatorType='named_entity', begin=192, end=196, result='O', metadata={}), Row(annotatorType='named_entity', begin=198, end=199, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=201, end=207, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=209, end=210, result='O', metadata={}), Row(annotatorType='named_entity', begin=212, end=220, result='I-ORG', metadata={}), Row(annotatorType='named_entity', begin=222, end=225, result='O', metadata={}), Row(annotatorType='named_entity', begin=227, end=235, result='O', metadata={}), Row(annotatorType='named_entity', begin=237, end=240, result='O', metadata={}), Row(annotatorType='named_entity', begin=242, end=245, result='O', metadata={}), Row(annotatorType='named_entity', begin=247, end=250, result='O', metadata={}), Row(annotatorType='named_entity', begin=252, end=255, result='O', metadata={}), Row(annotatorType='named_entity', begin=257, end=260, result='O', metadata={}), Row(annotatorType='named_entity', begin=262, end=271, result='O', metadata={}), Row(annotatorType='named_entity', begin=273, end=279, result='O', metadata={}), Row(annotatorType='named_entity', begin=281, end=281, result='O', metadata={}), Row(annotatorType='named_entity', begin=285, end=292, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=294, end=297, result='O', metadata={}), Row(annotatorType='named_entity', begin=299, end=303, result='O', metadata={}), Row(annotatorType='named_entity', begin=305, end=309, result='O', metadata={}), Row(annotatorType='named_entity', begin=311, end=317, result='O', metadata={} ...
# [Row(annotatorType='named_entity', begin=3, end=7, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=9, end=12, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=14, end=17, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=19, end=23, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=25, end=27, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=29, end=34, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=36, end=40, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=42, end=42, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=46, end=52, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=54, end=63, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=67, end=71, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=73, end=75, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=77, end=80, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=82, end=83, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=85, end=87, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=89, end=92, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=94, end=96, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=98, end=106, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=108, end=112, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=114, end=117, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=119, end=124, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=126, end=128, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=130, end=133, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=135, end=137, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=139, end=143, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=145, end=150, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=152, end=157, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=159, end=162, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=164, end=172, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=174, end=178, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=180, end=186, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=188, end=191, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=193, end=196, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=198, end=198, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=202, end=214, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=216, end=221, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=223, end=224, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=226, end=229, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=231, end=232, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=234, end=236, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=238, end=240, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=242, end=245, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=247, end=249, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=251, end=256, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=258, end=259, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=261, end=263, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=265, end=269, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=271, end=271, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=273, end=275, result='O\n', metadata={}), ...
# [Row(annotatorType='named_entity', begin=3, end=7, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=9, end=12, result='O', metadata={}), Row(annotatorType='named_entity', begin=14, end=17, result='O', metadata={}), Row(annotatorType='named_entity', begin=19, end=23, result='O', metadata={}), Row(annotatorType='named_entity', begin=25, end=27, result='O', metadata={}), Row(annotatorType='named_entity', begin=29, end=34, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=36, end=40, result='O', metadata={}), Row(annotatorType='named_entity', begin=42, end=42, result='O', metadata={}), Row(annotatorType='named_entity', begin=46, end=52, result='O', metadata={}), Row(annotatorType='named_entity', begin=54, end=63, result='O', metadata={}), Row(annotatorType='named_entity', begin=67, end=71, result='O', metadata={}), Row(annotatorType='named_entity', begin=73, end=75, result='O', metadata={}), Row(annotatorType='named_entity', begin=77, end=80, result='O', metadata={}), Row(annotatorType='named_entity', begin=82, end=83, result='O', metadata={}), Row(annotatorType='named_entity', begin=85, end=87, result='O', metadata={}), Row(annotatorType='named_entity', begin=89, end=92, result='O', metadata={}), Row(annotatorType='named_entity', begin=94, end=96, result='O', metadata={}), Row(annotatorType='named_entity', begin=98, end=106, result='O', metadata={}), Row(annotatorType='named_entity', begin=108, end=112, result='O', metadata={}), Row(annotatorType='named_entity', begin=114, end=117, result='O', metadata={}), Row(annotatorType='named_entity', begin=119, end=124, result='O', metadata={}), Row(annotatorType='named_entity', begin=126, end=128, result='O', metadata={}), Row(annotatorType='named_entity', begin=130, end=133, result='O', metadata={}), Row(annotatorType='named_entity', begin=135, end=137, result='O', metadata={}), Row(annotatorType='named_entity', begin=139, end=143, result='O', metadata={}), Row(annotatorType='named_entity', begin=145, end=150, result='O', metadata={}), Row(annotatorType='named_entity', begin=152, end=157, result='O', metadata={}), Row(annotatorType='named_entity', begin=159, end=162, result='O', metadata={}), Row(annotatorType='named_entity', begin=164, end=172, result='O', metadata={}), Row(annotatorType='named_entity', begin=174, end=178, result='O', metadata={}), Row(annotatorType='named_entity', begin=180, end=186, result='O', metadata={}), Row(annotatorType='named_entity', begin=188, end=191, result='O', metadata={}), Row(annotatorType='named_entity', begin=193, end=196, result='O', metadata={}), Row(annotatorType='named_entity', begin=198, end=198, result='O', metadata={}), Row(annotatorType='named_entity', begin=202, end=214, result='O', metadata={}), Row(annotatorType='named_entity', begin=216, end=221, result='O', metadata={}), Row(annotatorType='named_entity', begin=223, end=224, result='O', metadata={}), Row(annotatorType='named_entity', begin=226, end=229, result='O', metadata={}), Row(annotatorType='named_entity', begin=231, end=232, result='O', metadata={}), Row(annotatorType='named_entity', begin=234, end=236, result='O', metadata={}), Row(annotatorType='named_entity', begin=238, end=240, result='O', metadata={}), Row(annotatorType='named_entity', begin=242, end=245, result='O', metadata={}), Row(annotatorType='named_entity', begin=247, end=249, result='O', metadata={}), Row(annotatorType='named_entity', begin=251, end=256, result='O', metadata={}), Row(annotatorType='named_entity', begin=258, end=259, result='O', metadata={}), Row(annotatorType='named_entity', begin=261, end=263, result='O', metadata={}), Row(annotatorType='named_entity', begin=265, end=269, result='O', metadata={}), Row(annotatorType='named_entity', begin=271, end=271, result='O', metadata={}), Row(annotatorType='named_entity', begin=273, end=275, result='O', metadata={}), Row(annotatorType='named_entity', begin=277, end=284, result='O', metadata={}), Row(annotatorType='named_enti ...
# [Row(annotatorType='named_entity', begin=3, end=8, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=10, end=13, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=15, end=17, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=19, end=31, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=33, end=34, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=36, end=39, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=41, end=43, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=45, end=46, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=48, end=48, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=50, end=51, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=53, end=53, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=57, end=65, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=67, end=76, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=80, end=85, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=87, end=96, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=98, end=110, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=112, end=113, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=115, end=119, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=121, end=128, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=130, end=135, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=137, end=140, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=142, end=148, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=150, end=151, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=153, end=156, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=158, end=161, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=163, end=166, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=168, end=171, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=173, end=175, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=177, end=188, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=190, end=195, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=197, end=197, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=199, end=201, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=203, end=209, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=211, end=216, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=218, end=220, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=222, end=226, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=228, end=235, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=237, end=240, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=242, end=243, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=245, end=252, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=254, end=254, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=258, end=260, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=262, end=267, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=269, end=272, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=274, end=280, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=282, end=284, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=286, end=289, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=291, end=294, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=296, end=305, result=' ...
# [Row(annotatorType='named_entity', begin=3, end=8, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=10, end=13, result='O', metadata={}), Row(annotatorType='named_entity', begin=15, end=17, result='O', metadata={}), Row(annotatorType='named_entity', begin=19, end=31, result='O', metadata={}), Row(annotatorType='named_entity', begin=33, end=34, result='O', metadata={}), Row(annotatorType='named_entity', begin=36, end=39, result='O', metadata={}), Row(annotatorType='named_entity', begin=41, end=43, result='O', metadata={}), Row(annotatorType='named_entity', begin=45, end=46, result='O', metadata={}), Row(annotatorType='named_entity', begin=48, end=48, result='O', metadata={}), Row(annotatorType='named_entity', begin=50, end=51, result='O', metadata={}), Row(annotatorType='named_entity', begin=53, end=53, result='O', metadata={}), Row(annotatorType='named_entity', begin=57, end=65, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=67, end=76, result='O', metadata={}), Row(annotatorType='named_entity', begin=80, end=85, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=87, end=96, result='O', metadata={}), Row(annotatorType='named_entity', begin=98, end=110, result='O', metadata={}), Row(annotatorType='named_entity', begin=112, end=113, result='O', metadata={}), Row(annotatorType='named_entity', begin=115, end=119, result='O', metadata={}), Row(annotatorType='named_entity', begin=121, end=128, result='O', metadata={}), Row(annotatorType='named_entity', begin=130, end=135, result='O', metadata={}), Row(annotatorType='named_entity', begin=137, end=140, result='O', metadata={}), Row(annotatorType='named_entity', begin=142, end=148, result='O', metadata={}), Row(annotatorType='named_entity', begin=150, end=151, result='O', metadata={}), Row(annotatorType='named_entity', begin=153, end=156, result='O', metadata={}), Row(annotatorType='named_entity', begin=158, end=161, result='O', metadata={}), Row(annotatorType='named_entity', begin=163, end=166, result='O', metadata={}), Row(annotatorType='named_entity', begin=168, end=171, result='O', metadata={}), Row(annotatorType='named_entity', begin=173, end=175, result='O', metadata={}), Row(annotatorType='named_entity', begin=177, end=188, result='O', metadata={}), Row(annotatorType='named_entity', begin=190, end=195, result='O', metadata={}), Row(annotatorType='named_entity', begin=197, end=197, result='O', metadata={}), Row(annotatorType='named_entity', begin=199, end=201, result='O', metadata={}), Row(annotatorType='named_entity', begin=203, end=209, result='I-ORG', metadata={}), Row(annotatorType='named_entity', begin=211, end=216, result='O', metadata={}), Row(annotatorType='named_entity', begin=218, end=220, result='O', metadata={}), Row(annotatorType='named_entity', begin=222, end=226, result='O', metadata={}), Row(annotatorType='named_entity', begin=228, end=235, result='O', metadata={}), Row(annotatorType='named_entity', begin=237, end=240, result='O', metadata={}), Row(annotatorType='named_entity', begin=242, end=243, result='O', metadata={}), Row(annotatorType='named_entity', begin=245, end=252, result='O', metadata={}), Row(annotatorType='named_entity', begin=254, end=254, result='O', metadata={}), Row(annotatorType='named_entity', begin=258, end=260, result='O', metadata={}), Row(annotatorType='named_entity', begin=262, end=267, result='O', metadata={}), Row(annotatorType='named_entity', begin=269, end=272, result='O', metadata={}), Row(annotatorType='named_entity', begin=274, end=280, result='O', metadata={}), Row(annotatorType='named_entity', begin=282, end=284, result='O', metadata={}), Row(annotatorType='named_entity', begin=286, end=289, result='O', metadata={}), Row(annotatorType='named_entity', begin=291, end=294, result='O', metadata={}), Row(annotatorType='named_entity', begin=296, end=305, result='O', metadata={}), Row(annotatorType='named_entity', begin=307, end=308, result='O', metadata={}), Row(annotatorT ...
# [Row(annotatorType='named_entity', begin=3, end=7, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=9, end=18, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=20, end=23, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=25, end=29, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=31, end=35, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=37, end=38, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=40, end=41, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=43, end=45, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=47, end=55, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=57, end=57, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=61, end=66, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=68, end=77, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=81, end=83, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=85, end=89, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=91, end=99, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=101, end=105, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=107, end=108, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=110, end=118, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=120, end=125, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=127, end=130, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=132, end=134, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=136, end=140, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=142, end=146, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=148, end=149, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=151, end=155, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=157, end=164, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=166, end=171, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=173, end=179, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=181, end=182, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=184, end=187, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=189, end=192, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=194, end=202, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=204, end=204, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=206, end=208, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=210, end=216, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=218, end=226, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=228, end=233, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=235, end=245, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=247, end=250, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=252, end=260, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=262, end=262, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=266, end=270, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=272, end=279, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=281, end=286, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=288, end=294, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=296, end=297, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=299, end=303, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=305, end=306, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=308, end=311, resu ...
# ...
# [Row(annotatorType='named_entity', begin=3, end=9, result='O', metadata={}), Row(annotatorType='named_entity', begin=11, end=11, result='O', metadata={}), Row(annotatorType='named_entity', begin=13, end=19, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=21, end=24, result='O', metadata={}), Row(annotatorType='named_entity', begin=26, end=33, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=35, end=36, result='O', metadata={}), Row(annotatorType='named_entity', begin=38, end=40, result='O', metadata={}), Row(annotatorType='named_entity', begin=42, end=45, result='O', metadata={}), Row(annotatorType='named_entity', begin=47, end=48, result='O', metadata={}), Row(annotatorType='named_entity', begin=50, end=55, result='O', metadata={}), Row(annotatorType='named_entity', begin=57, end=65, result='O', metadata={}), Row(annotatorType='named_entity', begin=67, end=67, result='O', metadata={}), Row(annotatorType='named_entity', begin=71, end=80, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=82, end=82, result='O', metadata={}), Row(annotatorType='named_entity', begin=84, end=90, result='O', metadata={}), Row(annotatorType='named_entity', begin=92, end=101, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=105, end=111, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=113, end=116, result='O', metadata={}), Row(annotatorType='named_entity', begin=118, end=125, result='O', metadata={}), Row(annotatorType='named_entity', begin=127, end=128, result='O', metadata={}), Row(annotatorType='named_entity', begin=130, end=132, result='O', metadata={}), Row(annotatorType='named_entity', begin=134, end=137, result='O', metadata={}), Row(annotatorType='named_entity', begin=139, end=140, result='O', metadata={}), Row(annotatorType='named_entity', begin=142, end=144, result='O', metadata={}), Row(annotatorType='named_entity', begin=146, end=151, result='O', metadata={}), Row(annotatorType='named_entity', begin=153, end=159, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=161, end=173, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=175, end=176, result='O', metadata={}), Row(annotatorType='named_entity', begin=178, end=186, result='O', metadata={}), Row(annotatorType='named_entity', begin=188, end=189, result='O', metadata={}), Row(annotatorType='named_entity', begin=191, end=198, result='O', metadata={}), Row(annotatorType='named_entity', begin=200, end=201, result='O', metadata={}), Row(annotatorType='named_entity', begin=203, end=206, result='O', metadata={}), Row(annotatorType='named_entity', begin=208, end=210, result='O', metadata={}), Row(annotatorType='named_entity', begin=212, end=217, result='O', metadata={}), Row(annotatorType='named_entity', begin=219, end=221, result='O', metadata={}), Row(annotatorType='named_entity', begin=223, end=223, result='O', metadata={}), Row(annotatorType='named_entity', begin=227, end=232, result='O', metadata={}), Row(annotatorType='named_entity', begin=234, end=234, result='O', metadata={}), Row(annotatorType='named_entity', begin=236, end=242, result='O', metadata={}), Row(annotatorType='named_entity', begin=244, end=248, result='O', metadata={}), Row(annotatorType='named_entity', begin=250, end=256, result='O', metadata={}), Row(annotatorType='named_entity', begin=258, end=263, result='O', metadata={}), Row(annotatorType='named_entity', begin=265, end=265, result='O', metadata={}), Row(annotatorType='named_entity', begin=267, end=268, result='O', metadata={}), Row(annotatorType='named_entity', begin=270, end=275, result='O', metadata={}), Row(annotatorType='named_entity', begin=277, end=279, result='O', metadata={}), Row(annotatorType='named_entity', begin=281, end=281, result='O', metadata={}), Row(annotatorType='named_entity', begin=283, end=283, result='O', metadata={}), Row(annotatorType='named_entity', begin=285, end=292, result='O', metadata={}), Row( ...
# [Row(annotatorType='named_entity', begin=3, end=9, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=11, end=11, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=13, end=16, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=18, end=19, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=21, end=31, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=33, end=37, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=39, end=45, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=47, end=47, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=49, end=57, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=59, end=59, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=63, end=71, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=73, end=73, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=75, end=85, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=87, end=96, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=100, end=106, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=108, end=114, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=116, end=117, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=121, end=123, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=125, end=130, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=132, end=136, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=138, end=140, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=142, end=146, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=148, end=152, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=154, end=155, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=157, end=159, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=161, end=164, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=166, end=167, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=169, end=171, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=173, end=183, result='I-MISC\n', metadata={}), Row(annotatorType='named_entity', begin=187, end=193, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=195, end=202, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=204, end=206, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=208, end=216, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=218, end=219, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=221, end=228, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=230, end=230, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=234, end=235, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=237, end=240, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=242, end=247, result='I-PER\n', metadata={}), Row(annotatorType='named_entity', begin=249, end=249, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=251, end=257, result='I-LOC\n', metadata={}), Row(annotatorType='named_entity', begin=259, end=259, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=261, end=267, result='I-ORG\n', metadata={}), Row(annotatorType='named_entity', begin=269, end=269, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=271, end=275, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=277, end=278, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=280, end=283, result='O\n', metadata={}), Row(annotatorType='named_entity', begin=285, end=285, result='O\n', metadata={}), Row(annotatorType='named_e ...
# [Row(annotatorType='named_entity', begin=3, end=9, result='O', metadata={}), Row(annotatorType='named_entity', begin=11, end=11, result='O', metadata={}), Row(annotatorType='named_entity', begin=13, end=16, result='O', metadata={}), Row(annotatorType='named_entity', begin=18, end=19, result='O', metadata={}), Row(annotatorType='named_entity', begin=21, end=31, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=33, end=37, result='O', metadata={}), Row(annotatorType='named_entity', begin=39, end=45, result='O', metadata={}), Row(annotatorType='named_entity', begin=47, end=47, result='O', metadata={}), Row(annotatorType='named_entity', begin=49, end=57, result='O', metadata={}), Row(annotatorType='named_entity', begin=59, end=59, result='O', metadata={}), Row(annotatorType='named_entity', begin=63, end=71, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=73, end=73, result='O', metadata={}), Row(annotatorType='named_entity', begin=75, end=85, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=87, end=96, result='O', metadata={}), Row(annotatorType='named_entity', begin=100, end=106, result='O', metadata={}), Row(annotatorType='named_entity', begin=108, end=114, result='O', metadata={}), Row(annotatorType='named_entity', begin=116, end=117, result='O', metadata={}), Row(annotatorType='named_entity', begin=121, end=123, result='O', metadata={}), Row(annotatorType='named_entity', begin=125, end=130, result='O', metadata={}), Row(annotatorType='named_entity', begin=132, end=136, result='O', metadata={}), Row(annotatorType='named_entity', begin=138, end=140, result='O', metadata={}), Row(annotatorType='named_entity', begin=142, end=146, result='O', metadata={}), Row(annotatorType='named_entity', begin=148, end=152, result='O', metadata={}), Row(annotatorType='named_entity', begin=154, end=155, result='O', metadata={}), Row(annotatorType='named_entity', begin=157, end=159, result='O', metadata={}), Row(annotatorType='named_entity', begin=161, end=164, result='I-MISC', metadata={}), Row(annotatorType='named_entity', begin=166, end=167, result='O', metadata={}), Row(annotatorType='named_entity', begin=169, end=171, result='O', metadata={}), Row(annotatorType='named_entity', begin=173, end=183, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=187, end=193, result='O', metadata={}), Row(annotatorType='named_entity', begin=195, end=202, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=204, end=206, result='O', metadata={}), Row(annotatorType='named_entity', begin=208, end=216, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=218, end=219, result='O', metadata={}), Row(annotatorType='named_entity', begin=221, end=228, result='O', metadata={}), Row(annotatorType='named_entity', begin=230, end=230, result='O', metadata={}), Row(annotatorType='named_entity', begin=234, end=234, result='O', metadata={}), Row(annotatorType='named_entity', begin=235, end=235, result='O', metadata={}), Row(annotatorType='named_entity', begin=237, end=240, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=242, end=247, result='I-PER', metadata={}), Row(annotatorType='named_entity', begin=249, end=249, result='O', metadata={}), Row(annotatorType='named_entity', begin=251, end=257, result='I-LOC', metadata={}), Row(annotatorType='named_entity', begin=259, end=259, result='O', metadata={}), Row(annotatorType='named_entity', begin=261, end=267, result='I-ORG', metadata={}), Row(annotatorType='named_entity', begin=269, end=269, result='O', metadata={}), Row(annotatorType='named_entity', begin=271, end=275, result='O', metadata={}), Row(annotatorType='named_entity', begin=277, end=278, result='O', metadata={}), Row(annotatorType='named_entity', begin=280, end=283, result='O', metadata={}), Row(annotatorType='named_entity', begin=285, end=285, result='O', metadata={}), Row(annotatorType='named_entity', begin=287, end=293, result='O' ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
